# %%
import cv2
import os
import numpy as np

def mask_background_keep_largest(
    input_folder: str,
    output_folder: str,
    bg_color: tuple,
    tolerance: int = 10
):
    """
    Process each image in `input_folder` to create a binary mask by removing a uniform background
    and then keep only the largest connected white region in the mask, removing any small lines or patches.
    
    Args:
        input_folder (str): Path to the folder containing the input images.
        output_folder (str): Path where the generated masks will be saved.
        bg_color (tuple): The background color in BGR format (e.g., (59, 59, 59)).
        tolerance (int): Tolerance for color difference. Pixels with a total difference <= this
                         value are treated as background.
    """
    if not os.path.exists(output_folder):
        os.makedirs(output_folder)

    for filename in os.listdir(input_folder):
        if filename.lower().endswith(('.png', '.jpg', '.jpeg')):
            image_path = os.path.join(input_folder, filename)
            img = cv2.imread(image_path)
            if img is None:
                print(f"Warning: Could not load image {image_path}")
                continue

            # Create an array matching the background color
            bg_array = np.full(img.shape, bg_color, dtype=np.uint8)

            # Compute the absolute difference and sum across color channels
            diff = cv2.absdiff(img, bg_array)
            diff_sum = np.sum(diff, axis=2)

            # Create a binary mask: > tolerance => foreground, else background
            mask = np.uint8((diff_sum > tolerance).astype(np.uint8)) * 255

            # Optionally, a morphological opening to remove tiny noise
            kernel = np.ones((3, 3), np.uint8)
            mask = cv2.morphologyEx(mask, cv2.MORPH_OPEN, kernel)

            # Identify connected components
            num_labels, labels, stats, centroids = cv2.connectedComponentsWithStats(mask, connectivity=8)

            # If there's only background (num_labels < 2), skip
            if num_labels < 2:
                # If no foreground region found, just save the empty mask
                output_path = os.path.join(output_folder, filename)
                cv2.imwrite(output_path, mask)
                print(f"No foreground found in {filename}; saved empty mask.")
                continue

            # Keep only the largest connected component (label != 0 is background)
            largest_label = 1
            largest_area = stats[1, cv2.CC_STAT_AREA]

            for label_id in range(2, num_labels):
                area = stats[label_id, cv2.CC_STAT_AREA]
                if area > largest_area:
                    largest_area = area
                    largest_label = label_id

            # Create a mask containing only the largest component
            largest_mask = np.zeros_like(mask)
            largest_mask[labels == largest_label] = 255

            # Save the refined mask
            output_path = os.path.join(output_folder, filename)
            cv2.imwrite(output_path, largest_mask)
            print(f"Processed and saved mask for: {filename}")

if __name__ == "__main__":
    # Example usage
    input_dir = r"D:\ASCC_parts_extended\workspace\dist_far\train"  # Folder with input images
    output_dir = r"D:\ASCC_parts_extended\workspace\dist_far\masks"  # Folder to save masks

    # Background color in BGR (59,59,59 in your example)
    bg_color = (59, 59, 59)

    # Tolerance for background difference
    tolerance = 10

    mask_background_keep_largest(input_dir, output_dir, bg_color, tolerance)
# Out:
# Processed and saved mask for: 0001.png
# Processed and saved mask for: 0002.png
# Processed and saved mask for: 0003.png
# Processed and saved mask for: 0004.png
# Processed and saved mask for: 0005.png
# Processed and saved mask for: 0006.png
# Processed and saved mask for: 0007.png
# Processed and saved mask for: 0008.png
# Processed and saved mask for: 0009.png
# Processed and saved mask for: 0010.png
# Processed and saved mask for: 0011.png
# Processed and saved mask for: 0012.png
# Processed and saved mask for: 0013.png
# Processed and saved mask for: 0014.png
# Processed and saved mask for: 0015.png
# Processed and saved mask for: 0016.png
# Processed and saved mask for: 0017.png
# Processed and saved mask for: 0018.png
# Processed and saved mask for: 0019.png
# Processed and saved mask for: 0020.png
# Processed and saved mask for: 0021.png
# Processed and saved mask for: 0022.png
# Processed and saved mask for: 0023.png
# Processed and saved mask for: 0024.png
# Processed and saved mask for: 0025.png
# Processed and saved mask for: 0026.png
# Processed and saved mask for: 0027.png
# Processed and saved mask for: 0028.png
# Processed and saved mask for: 0029.png
# Processed and saved mask for: 0030.png
# Processed and saved mask for: 0031.png
# Processed and saved mask for: 0032.png
# Processed and saved mask for: 0033.png
# Processed and saved mask for: 0034.png
# Processed and saved mask for: 0035.png
# Processed and saved mask for: 0036.png
# Processed and saved mask for: 0037.png
# Processed and saved mask for: 0038.png
# Processed and saved mask for: 0039.png
# Processed and saved mask for: 0040.png
# Processed and saved mask for: 0041.png
# Processed and saved mask for: 0042.png
# Processed and saved mask for: 0043.png
# Processed and saved mask for: 0044.png
# Processed and saved mask for: 0045.png
# Processed and saved mask for: 0046.png
# Processed and saved mask for: 0047.png
# Processed and saved mask for: 0048.png
# Processed and saved mask for: 0049.png
# Processed and saved mask for: 0050.png
# Processed and saved mask for: 0051.png
# Processed and saved mask for: 0052.png
# Processed and saved mask for: 0053.png
# Processed and saved mask for: 0054.png
# Processed and saved mask for: 0055.png
# Processed and saved mask for: 0056.png
# Processed and saved mask for: 0057.png
# Processed and saved mask for: 0058.png
# Processed and saved mask for: 0059.png
# Processed and saved mask for: 0060.png
# Processed and saved mask for: 0061.png
# Processed and saved mask for: 0062.png
# Processed and saved mask for: 0063.png
# Processed and saved mask for: 0064.png
# Processed and saved mask for: 0065.png
# Processed and saved mask for: 0066.png
# Processed and saved mask for: 0067.png
# Processed and saved mask for: 0068.png
# Processed and saved mask for: 0069.png
# Processed and saved mask for: 0070.png
# Processed and saved mask for: 0071.png
# Processed and saved mask for: 0072.png
# Processed and saved mask for: 0073.png
# Processed and saved mask for: 0074.png
# Processed and saved mask for: 0075.png
# Processed and saved mask for: 0076.png
# Processed and saved mask for: 0077.png
# Processed and saved mask for: 0078.png
# Processed and saved mask for: 0079.png
# Processed and saved mask for: 0080.png
# Processed and saved mask for: 0081.png
# Processed and saved mask for: 0082.png
# Processed and saved mask for: 0083.png
# Processed and saved mask for: 0084.png
# Processed and saved mask for: 0085.png
# Processed and saved mask for: 0086.png
# Processed and saved mask for: 0087.png
# Processed and saved mask for: 0088.png
# Processed and saved mask for: 0089.png
# Processed and saved mask for: 0090.png
# Processed and saved mask for: 0091.png
# Processed and saved mask for: 0092.png
# Processed and saved mask for: 0093.png
# Processed and saved mask for: 0094.png
# Processed and saved mask for: 0095.png
# Processed and saved mask for: 0096.png
# Processed and saved mask for: 0097.png
# Processed and saved mask for: 0098.png
# Processed and saved mask for: 0099.png
# Processed and saved mask for: 0100.png
# Processed and saved mask for: 0101.png
# Processed and saved mask for: 0102.png
# Processed and saved mask for: 0103.png
# Processed and saved mask for: 0104.png
# Processed and saved mask for: 0105.png
# Processed and saved mask for: 0106.png
# Processed and saved mask for: 0107.png
# Processed and saved mask for: 0108.png
# Processed and saved mask for: 0109.png
# Processed and saved mask for: 0110.png
# Processed and saved mask for: 0111.png
# Processed and saved mask for: 0112.png
# Processed and saved mask for: 0113.png
# Processed and saved mask for: 0114.png
# Processed and saved mask for: 0115.png
# Processed and saved mask for: 0116.png
# Processed and saved mask for: 0117.png
# Processed and saved mask for: 0118.png
# Processed and saved mask for: 0119.png
# Processed and saved mask for: 0120.png
# Processed and saved mask for: 0121.png
# Processed and saved mask for: 0122.png
# Processed and saved mask for: 0123.png
# Processed and saved mask for: 0124.png
# Processed and saved mask for: 0125.png
# Processed and saved mask for: 0126.png
# Processed and saved mask for: 0127.png
# Processed and saved mask for: 0128.png
# Processed and saved mask for: 0129.png
# Processed and saved mask for: 0130.png
# Processed and saved mask for: 0131.png
# Processed and saved mask for: 0132.png
# Processed and saved mask for: 0133.png
# Processed and saved mask for: 0134.png
# Processed and saved mask for: 0135.png
# Processed and saved mask for: 0136.png
# Processed and saved mask for: 0137.png
# Processed and saved mask for: 0138.png
# Processed and saved mask for: 0139.png
# Processed and saved mask for: 0140.png
# Processed and saved mask for: 0141.png
# Processed and saved mask for: 0142.png
# Processed and saved mask for: 0143.png
# Processed and saved mask for: 0144.png
# Processed and saved mask for: 0145.png
# Processed and saved mask for: 0146.png
# Processed and saved mask for: 0147.png
# Processed and saved mask for: 0148.png
# Processed and saved mask for: 0149.png
# Processed and saved mask for: 0150.png
# Processed and saved mask for: 0151.png
# Processed and saved mask for: 0152.png
# Processed and saved mask for: 0153.png
# Processed and saved mask for: 0154.png
# Processed and saved mask for: 0155.png
# Processed and saved mask for: 0156.png
# Processed and saved mask for: 0157.png
# Processed and saved mask for: 0158.png
# Processed and saved mask for: 0159.png
# Processed and saved mask for: 0160.png
# Processed and saved mask for: 0161.png
# Processed and saved mask for: 0162.png
# Processed and saved mask for: 0163.png
# Processed and saved mask for: 0164.png
# Processed and saved mask for: 0165.png
# Processed and saved mask for: 0166.png
# Processed and saved mask for: 0167.png
# Processed and saved mask for: 0168.png
# Processed and saved mask for: 0169.png
# Processed and saved mask for: 0170.png
# Processed and saved mask for: 0171.png
# Processed and saved mask for: 0172.png
# Processed and saved mask for: 0173.png
# Processed and saved mask for: 0174.png
# Processed and saved mask for: 0175.png
# Processed and saved mask for: 0176.png
# Processed and saved mask for: 0177.png
# Processed and saved mask for: 0178.png
# Processed and saved mask for: 0179.png
# Processed and saved mask for: 0180.png
# Processed and saved mask for: 0181.png
# Processed and saved mask for: 0182.png
# Processed and saved mask for: 0183.png
# Processed and saved mask for: 0184.png
# Processed and saved mask for: 0185.png
# Processed and saved mask for: 0186.png
# Processed and saved mask for: 0187.png
# Processed and saved mask for: 0188.png
# Processed and saved mask for: 0189.png
# Processed and saved mask for: 0190.png
# Processed and saved mask for: 0191.png
# Processed and saved mask for: 0192.png
# Processed and saved mask for: 0193.png
# Processed and saved mask for: 0194.png
# Processed and saved mask for: 0195.png
# Processed and saved mask for: 0196.png
# Processed and saved mask for: 0197.png
# Processed and saved mask for: 0198.png
# Processed and saved mask for: 0199.png
# Processed and saved mask for: 0200.png

# %%
import json
import os

# Specify your input JSON file and the output JSON filename
input_json = "transforms.json"  # Change this to the path of your JSON file
output_json = "transforms_with_masks.json"

# Folder where mask images are stored (relative or absolute)
mask_folder = "masks"  # e.g., if your masks are in a folder called "masks"

# Load the original JSON
with open(input_json, "r") as f:
    data = json.load(f)

# Process each frame in the JSON file
for frame in data.get("frames", []):
    # Get the base filename from the file_path (e.g., "0001.png")
    image_filename = os.path.basename(frame["file_path"])
    
    # Create the corresponding mask path; adjust extension if needed.
    # For example, if your mask files are JPEG, you could replace the extension:
    # mask_filename = os.path.splitext(image_filename)[0] + ".jpeg"
    # Here we simply assume the mask has the same filename.
    mask_filename = image_filename

    # Create the relative path to the mask image
    frame["mask_path"] = os.path.join(mask_folder, mask_filename)

# (Optional) Save the updated JSON into a new file
with open(output_json, "w") as f:
    json.dump(data, f, indent=4)

print(f"Updated JSON has been saved to {output_json}")
# Out:
# Updated JSON has been saved to transforms_with_masks.json
